# %%
#畫圖(train data)
from IPython.display import Image
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.scatter(y_train_pred,  
            y_train_pred - y_train, 
            c='steelblue',
            edgecolor='white',
            marker='o', 
            s=30,
            alpha=0.9,
            label='training data')

#plt.scatter(y_test_pred,  
#            y_test_pred - y_test, 
#            c='limegreen',
#            edgecolor='white',
#            marker='s', 
#            s=35,
#            alpha=0.9,
#            label='test data')
plt.title('training data prediction')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.legend(loc='upper left')
plt.hlines(y=0, xmin=0, xmax=1000000, lw=2, color='black')
plt.xlim([0, 1000000])
plt.ylim([-1000000, 1000000])
plt.tight_layout()
#plt.savefig('/Users/Howard/Desktop/randomforest_train_data_prediction.png', dpi=400)
plt.show()

# %%
#畫圖(test data)
from IPython.display import Image
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

#plt.scatter(y_train_pred,  
#            y_train_pred - y_train, 
#           c='steelblue',
#           edgecolor='white',
#            marker='o', 
#           s=35,
#           alpha=0.9,
#           label='training data')

plt.scatter(y_test_pred,  
            y_test_pred - y_test, 
            c='limegreen',
            edgecolor='white',
            marker='s', 
            s=25,
            alpha=0.9,
            label='test data')

plt.title('test data prediction')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.legend(loc='upper left')
plt.hlines(y=0, xmin=0, xmax=1000000, lw=2, color='black')
plt.xlim([0, 1000000])
plt.ylim([-1000000, 1000000])
plt.tight_layout()
#plt.savefig('/Users/Howard/Desktop/randomforest_test_data_prediction.png', dpi=400)
plt.show()
